# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)]

#Create empty lists for study time classifications:
#1(a) Low: less than 3 hours:
study_low =[]
#b : Moderate: between 3 and 5 hours.
study_moderate =[]
#c :High: more than 5 hours.
study_high =[]

## Task 2: Classify study hours
for study, entertainment, sleep in time_data:
    if study < 3:
        study_low.append(study)
    elif 3 <= study <= 5:
        study_moderate.append(study)
    else:
        study_high.append(study)

#Task 3
print("Low study time (< 3 hours):", study_low)
print("Moderate study time (3–5 hours):", study_moderate)
print("High study time (> 5 hours):", study_high)
# Out:
# Low study time (< 3 hours): [2.5, 1.5, 2.0, 2.5]
# Moderate study time (3–5 hours): [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study time (> 5 hours): [5.5, 6.0]

# %%
#Task 2. Based on Data – Answer all the Questions:
#1. How many days had low study time?
low_day = len(study_low)
print("The number of days which had low study time is ", low_day)
#2. How many days had moderate study time?
mod_day = len(study_moderate)
print("The number of days which had moderate study time  ", mod_day)
#3. How many days had high study time?
high_day = len(study_high)
print("The number of days which had high study time is ", high_day)
# Out:
# The number of days which had low study time is  4
# The number of days which had moderate study time   9
# The number of days which had high study time is  2

# %%
#Task 3. Convert Study Hours to Minutes:
#Convert each study hour value into minutes and store it in a new list called study_minutes.
study_minutes = []
for study,entertainment, sleep in time_data:
  study_minutes.append(study*60)
#2. Store the results in the new list.
nlist=[study_minutes]
#3. Print the converted values.
print(nlist)
# Out:
# [[210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]]

# %%
#Task 4. Analyze Average Time Use:
#1. Create empty lists for study_hours, entertainment_hours, and sleep_hours.
study_hours = []
entertainment_hours = []
sleep_hours = []
#2. Iterate over time_data and extract values into each list.
for study,entertainment,sleep in time_data:
  study_hours.append(study)
  entertainment_hours.append(entertainment)
  sleep_hours.append(sleep)
#3. Calculate and print:
#(a) Average hours spent studying.
avg_hour = sum(study_hours) /len(study_hours)
#(b) Average hours spent on entertainment.
avg_en = sum(entertainment_hours)/len(entertainment_hours)
#(c) Average hours spent sleeping.
avg_sleep = sum(sleep_hours)/len(sleep_hours)
print("Average hour os study is",avg_hour)
print("Average hour of entertainment is",avg_en)
print("Average hour of sleep is",avg_sleep)
# Out:
# Average hour os study is 3.7
# Average hour of entertainment is 2.5
# Average hour of sleep is 7.166666666666667

# %%
#Task 5. Visualization - Study vs Sleep Pattern:
#1. Import matplotlib.pyplot as plt.
import matplotlib.pyplot as plt
#2. Plot a scatter plot with:
# x-axis: Study hours
# y-axis: Sleep hours
plt.scatter(study_hours, sleep_hours, color='brown')
plt.title("Study Hours vs Sleep Hours")
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.grid(True)
plt.show()

# %%
#• Write a recursive function sum_nested_list(nested_list) that:
1#. Takes a nested list (a list that can contain numbers or other lists of numbers) as input.
def sum_nested_list(lst):
    total = 0
    for a in lst:
        if type(a) == list:
            total += sum_nested_list(a)
        else:
            total += a
    return total

#2. Sums all numbers at every depth level of the list, regardless of how deeply nested the number are.
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
print("Total sum:", sum_nested_list(nested_list))
# Out:
# Total sum: 36

# %%
#Task 2
#• Write a recursive function generate_permutations(s) that:
#Takes a string s as input and returns a list of all unique permutations.
def generate_permutations(s):
    if len(s) == 1:
        return [s]

    perms = []
    for i, char in enumerate(s):
        # Generate permutations of the remaining string
        remaining = s[:i] + s[i+1:]
        for p in generate_permutations(remaining):
            perms.append(char + p)

    return list(set(perms))  # Remove duplicates

# Test with strings like "abc" and "aab"
print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['acb', 'cab', 'bca', 'abc', 'bac', 'cba']
# ['baa', 'aba', 'aab']

# %%
# Write a recursive function calculate_directory_size(directory) where:
# The function should return the total size of the directory, including all nested subdirectories.
def calculate_directory_size(directory):
    total_size = 0
    for name, value in directory.items():
        if isinstance(value, dict):  # It's a subdirectory
            total_size += calculate_directory_size(value)  # Recursive call
        else:  # It's a file
            total_size += value
    return total_size
#Test the function with a sample directory structure.
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}
total_size = calculate_directory_size(directory_structure)
print("Total directory size:", total_size, "KB")
# Out:
# Total directory size: 1400 KB

# %%
#Task 1 - Coin Change Problem:
#1. Write a function min_coins(coins, amount) that:
#Uses DP to calculate the minimum number of coins needed to make up the amount.
def min_coins(coins, amount):
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0
    for i in range(1, amount + 1):
        for coin in coins:
            if i - coin >= 0:
                dp[i] = min(dp[i], dp[i - coin] + 1)
    return dp[amount] if dp[amount] != float('inf') else -1
#Test with coins = [1, 2, 5] and amount = 11. The result should be 3
coins = [1, 2, 5]
amount = 11
print("Minimum coins that is needed are:", min_coins(coins, amount))
# Out:
# Minimum coins that is needed are: 3

# %%
#1. Write a function longest_common_subsequence(s1, s2) that:
# Uses DP to find the length of the LCS of two strings s1 and s2.
def longest_common_subsequence(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = 1 + dp[i - 1][j - 1]
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]
#Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").
print(longest_common_subsequence("abcde", "ace"))
# Out:
# 3

# %%
#1. Write a function knapsack(weights, values, capacity) that:
#• Uses DP to determine the maximum value that can be achieved within the given weight capacity.
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] > w:
                dp[i][w] = dp[i - 1][w]
            else:
                dp[i][w] = max(
                    dp[i - 1][w],
                    values[i - 1] + dp[i - 1][w - weights[i - 1]])
    return dp[n][capacity]
#Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The re-
#sult should be 9.
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
print(knapsack(weights, values, capacity))
# Out:
# 9
